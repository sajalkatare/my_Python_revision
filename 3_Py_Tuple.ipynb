# %% [markdown]
# # Basic of Tuples

# %% [markdown]
# * ##### Tuple is a collection of Python objects much like a list.
#
# * ##### The sequence of values stored in a tuple can be of any type, and they are indexed by integers.
#
# * ##### Values of a tuple are syntactically separated by ‘commas’. Although it is not necessary, it is more common to define a tuple by closing the sequence of values in parentheses.

# %% [markdown]
# <font color='red'>Tuple is immutable; means we can noy update value in Tuple.</font>

# %% [markdown]
# <font color='blue'>To change value of tuple, you can change it to list and update the value.</font>

# %%
#Creating an empty Tuple
Tuple1 = ()
# Out:
#   File "<ipython-input-1-91f1a0b1a5bb>", line 2
#     Tuple1 = (
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
tuple2 =(3)
type(tuple2)
# Out:
# int

# %% [markdown]
# ##### So the single value in () will not be consider as tuple.
# ##### To solve this we need to add one comma.

# %%
tuple2 = (3,)
type(tuple2)
# Out:
# tuple

# %%
# another method, without the ()

tuple3 = 4,5

type(tuple3)
# Out:
# tuple

# %%
# Creating Tuple with mix datatype

tuple4 = (1,32,4.5, "sajal", [2,5,"katare"], (5,6), {'d': 10,'e': 20})
tuple4
# Out:
# (1, 32, 4.5, 'sajal', [2, 5, 'katare'], (5, 6), {'d': 10, 'e': 20})

# %% [markdown]
# * ### Concatination

# %%
# Concatenaton of tuples
Tuple1 = (0, 1, 2, 3)
Tuple2 = ('Geeks', 'For', 'Geeks')
 
Tuple3 = Tuple1 + Tuple2
print(Tuple1)
print(Tuple2)
Tuple3
# Out:
# (0, 1, 2, 3)
# ('Geeks', 'For', 'Geeks')
# (0, 1, 2, 3, 'Geeks', 'For', 'Geeks')

# %% [markdown]
# * ### Slicing and Indexing of Tuple

# %% [markdown]
# ##### Slicing and Indexing of tuple is similar too List

# %% [markdown]
# * ### Some Other Functions

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
