# %%
import pandas as pd

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",
                           sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.tail()
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 151          152         1       1  Pears, Mrs. Thomas (Edith Wearne)  female
# 152          153         0       3                   Meo, Mr. Alfonzo    male
# 153          154         0       3    van Billiard, Mr. Austin Blyler    male
# 154          155         0       3              Olsen, Mr. Ole Martin    male
# 155          156         0       1        Williams, Mr. Charles Duane    male
#
#       Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 151  22.0      1      0      113776  66.6000    C2        S
# 152  55.5      0      0  A.5. 11206   8.0500   NaN        S
# 153  40.5      0      2    A/5. 851  14.5000   NaN        S
# 154   NaN      0      0   Fa 265302   7.3125   NaN        S
# 155  51.0      0      1    PC 17597  61.3792   NaN        C

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Describe()

# %% [markdown]
# #### Describe give you statistical analysis of dataset.
#
# * #### By default Only for numerical data.

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %% [markdown]
# #### Describing Categorical Data

# %%
#extract non numrical columns
titanic_train.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
#now take out only true values
titanic_train.dtypes[titanic_train.dtypes == 'object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
#now take out only true values and their index
titanic_train.dtypes[titanic_train.dtypes == 'object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#Now call my whole datafram with these specific columns
titanic_train_1 = titanic_train[titanic_train.dtypes[titanic_train.dtypes == 'object'].index]

# %%
titanic_train_1
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
#Describe columns
titanic_train_1.describe()
# Out:
#                             Name   Sex  Ticket Cabin Embarked
# count                        156   156     156    31      155
# unique                       156     2     145    28        3
# top     Allen, Mr. William Henry  male  349909   D26        S
# freq                           1   100       2     2      110

# %% [markdown]
# ### Print Column Name

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_train['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
# Select multiple columns
titanic_train[['PassengerId', 'Survived']]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 151          152         1
# 152          153         0
# 153          154         0
# 154          155         0
# 155          156         0
#
# [156 rows x 2 columns]

# %% [markdown]
# #### Adding New Column with Constant Value

# %%
titanic_train['sudh'] = 'kumar'

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(titanic_train['Pclass'])
# Out:
# pandas.core.series.Series

# %%
pd.Categorical(titanic_train['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %% [markdown]
# #### 3 different type of classes are available

# %% [markdown]
# #### Checking Null Values

# %%
titanic_train['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 151    22.0
# 152    55.5
# 153    40.5
# 154     NaN
# 155    51.0
# Name: Age, Length: 156, dtype: float64

# %%
# give true if value is null
titanic_train['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
# Filter index where value is null
(titanic_train['Age'].isnull() == True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
import numpy as np

# %%
#np.where give you index places

np.where(titanic_train['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
# cross check at 5th index

titanic_train['Age'][5]
# Out:
# nan

# %% [markdown]
# #### Select Row Index where max fare has been charged

# %%
titanic_train['Fare'] == max(titanic_train['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Fare, Length: 156, dtype: bool

# %%
np.where(titanic_train['Fare'] == max(titanic_train['Fare']))
# Out:
# (array([27, 88], dtype=int64),)

# %% [markdown]
# #### Select Row Index where sex is male

# %%
np.where(titanic_train['Sex'] == 'male')
# Out:
# (array([  0,   4,   5,   6,   7,  12,  13,  16,  17,  20,  21,  23,  26,
#          27,  29,  30,  33,  34,  35,  36,  37,  42,  45,  46,  48,  50,
#          51,  54,  55,  57,  59,  60,  62,  63,  64,  65,  67,  69,  70,
#          72,  73,  74,  75,  76,  77,  78,  80,  81,  83,  86,  87,  89,
#          90,  91,  92,  93,  94,  95,  96,  97,  99, 101, 102, 103, 104,
#         105, 107, 108, 110, 112, 115, 116, 117, 118, 120, 121, 122, 124,
#         125, 126, 127, 129, 130, 131, 134, 135, 137, 138, 139, 143, 144,
#         145, 146, 148, 149, 150, 152, 153, 154, 155], dtype=int64),)

# %% [markdown]
# ### Selecting Rows

# %% [markdown]
# ### iloc

# %%
# PRint first index  (this will be second row)
titanic_train.iloc[1]
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# sudh                                                       kumar
# Name: 1, dtype: object

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# PRint first index  (this will be second row)
titanic_train.iloc[[1,2]]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   sudh
# 1      0          PC 17599  71.2833   C85        C  kumar
# 2      0  STON/O2. 3101282   7.9250   NaN        S  kumar

# %% [markdown]
# #### Print Max fare rows

# %%
titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare        Cabin Embarked   sudh
# 27  19.0      3      2  19950  263.0  C23 C25 C27        S  kumar
# 88  23.0      3      2  19950  263.0  C23 C25 C27        S  kumar

# %%
#Print name of person who gave max fare

(titanic_train.iloc[np.where(titanic_train['Fare'] == max(titanic_train['Fare']))])['Name']
# Out:
# 27    Fortune, Mr. Charles Alexander
# 88        Fortune, Miss. Mabel Helen
# Name: Name, dtype: object

# %% [markdown]
# #### Print Person Name who all are Survived

# %%
titanic_train['Survived'] == 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 151     True
# 152    False
# 153    False
# 154    False
# 155    False
# Name: Survived, Length: 156, dtype: bool

# %%
np.where(titanic_train['Survived'] == 1)
# Out:
# (array([  1,   2,   3,   8,   9,  10,  11,  15,  17,  19,  21,  22,  23,
#          25,  28,  31,  32,  36,  39,  43,  44,  47,  52,  53,  55,  56,
#          58,  61,  65,  66,  68,  74,  78,  79,  81,  82,  84,  85,  88,
#          97,  98, 106, 107, 109, 123, 125, 127, 128, 133, 136, 141, 142,
#         146, 151], dtype=int64),)

# %%
titanic_train.iloc[np.where(titanic_train['Survived'] == 1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 25            26         1       3
# 28            29         1       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 39            40         1       3
# 43            44         1       2
# 44            45         1       3
# 47            48         1       3
# 52            53         1       1
# 53            54         1       2
# 55            56         1       1
# ...

# %%
(titanic_train.iloc[np.where(titanic_train['Survived'] == 1)])['Name']
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# 17                          Williams, Mr. Charles Eugene
# 19                               Masselmani, Mrs. Fatima
# 21                                 Beesley, Mr. Lawrence
# 22                           McGowan, Miss. Anna "Annie"
# 23                          Sloper, Mr. William Thompson
# 25     Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 28                         O'Dwyer, Miss. Ellen "Nellie"
# 31        Spencer, Mrs. William Augustus (Marie Eugenie)
# ...

# %%
# count how many Person survived

len((titanic_train.iloc[np.where(titanic_train['Survived'] == 1)])['Name'])
# Out:
# 54

# %% [markdown]
# ### Creating New Dummy Data

# %%
lables = ['a','b','c','d']
list_1 = [12,45,67]
array = np.array(list_1)
d = {'a': 34,'b':30,'c':23}

# %%
#### change series to dataframe

pd.Series(list_1)
# Out:
# 0    12
# 1    45
# 2    67
# dtype: int64

# %%
# givig my own indexes

s1 = pd.Series(list_1,index =['sajal','katare', 'XyZ'])

# %%
s1[0]
# Out:
# 12

# %%
s1['sajal']
# Out:
# 12

# %%
#### change Array to dataframe

pd.Series(array)
# Out:
# 0    12
# 1    45
# 2    67
# dtype: int32

# %%
#### change Disctionary to dataframe

s = pd.Series(d)
s
# Out:
# a    34
# b    30
# c    23
# dtype: int64

# %% [markdown]
# ##### Here Key will become index.

# %%
s['c']
# Out:
# 23

# %%
s1 = pd.Series([1,2,3,4,5], index = ['a','b','c','d','e'])
s1
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s2 = pd.Series([7,2,8,4,5], index = ['a','b','c','c','e'])
s2
# Out:
# a    7
# b    2
# c    8
# c    4
# e    5
# dtype: int64

# %%
# What happen if you give duplicate index name

s2['c']
# Out:
# c    8
# c    4
# dtype: int64

# %% [markdown]
# ##### But by default numrical index will ahve uniques value and give single result

# %% [markdown]
# ### Adding 2 Datafranme

# %%
s1+s2
# Out:
# a     8.0
# b     4.0
# c    11.0
# c     7.0
# d     NaN
# e    10.0
# dtype: float64

# %% [markdown]
# ##### Here Same columns will be added. a with a, b with b, d is not available in S2 dataframe so it is NaN.

# %%
s3 = s1*s2
s3
# Out:
# a     7.0
# b     4.0
# c    24.0
# c    12.0
# d     NaN
# e    25.0
# dtype: float64

# %%
s3.iloc['a']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-d42880962040> in <module>
# ----> 1 s3.iloc['a']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1496             key = item_from_zerodim(key)
#    1497             if not is_integer(key):
# -> 1498                 raise TypeError("Cannot index by location index with a non-integer key")
#    1499
#    1500             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %% [markdown]
# * #### Above code will not work because iloc means integere location, so it will work only with numerical indexes.

# %% [markdown]
# * #### To solve above issue we can use loc function which will take index names.

# %%
s3.loc['a']
# Out:
# 7.0

# %% [markdown]
# ### Importing New dataset for Practice

# %%
from numpy.random import randn as rn

# %%
rn(5,5)
# Out:
# array([[ 0.11670531,  1.09050671, -0.52547774,  0.18820968,  1.20859521],
#        [ 0.45069341,  0.07833156,  0.9817232 , -1.57765212,  0.10621756],
#        [ 0.81928492, -1.04097221, -1.00945087,  0.16495489, -0.96996268],
#        [-0.24290638,  1.0541156 , -0.89515833, -0.69891387, -0.38850992],
#        [ 0.49687265,  0.6730627 , -0.32732997, -0.39579847, -2.06124776]])

# %%
type(rn)
# Out:
# builtin_function_or_method

# %%
# change it to datafram

pd.DataFrame(rn(5,5))
# Out:
#           0         1         2         3         4
# 0  0.130305  0.728174  0.199901 -0.236036  0.704770
# 1  0.244530 -1.123554  1.648160  0.939737 -0.352421
# 2  0.706109  1.209919 -1.389113  0.719876 -0.147471
# 3 -0.584466 -1.084041 -0.218209  1.913487  0.562469
# 4 -1.253608  0.740333 -0.560942 -0.046698  0.819376

# %%
# make data frame and give index name and column name



df = pd.DataFrame(rn(5,5), index = ['a','b','c','d','e'], columns = ['x','y','z','u','v'])
df
# Out:
#           x         y         z         u         v
# a  1.476070  0.068429 -0.567742  0.231227  0.068974
# b -0.720544  1.079304  0.317636  0.094377 -0.337972
# c  1.201157  1.958769 -1.099610  0.592995  0.177542
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836
# e  1.668007  0.573856  0.468277 -0.706752  0.411905

# %%
df.iloc[1]
# Out:
# x   -0.720544
# y    1.079304
# z    0.317636
# u    0.094377
# v   -0.337972
# Name: b, dtype: float64

# %%
# extract 0 and 3 index

df.iloc[[0,3]]
# Out:
#           x         y         z         u         v
# a  1.476070  0.068429 -0.567742  0.231227  0.068974
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836

# %%
# extract from 0 to 3 rows

df.iloc[0:3]
# Out:
#           x         y         z         u         v
# a  1.476070  0.068429 -0.567742  0.231227  0.068974
# b -0.720544  1.079304  0.317636  0.094377 -0.337972
# c  1.201157  1.958769 -1.099610  0.592995  0.177542

# %%
# Row with skipping rows


df.iloc[0:3:2]
# Out:
#           x         y         z         u         v
# a  1.476070  0.068429 -0.567742  0.231227  0.068974
# c  1.201157  1.958769 -1.099610  0.592995  0.177542

# %%
# Extract with index name

df.loc[['a','b']]
# Out:
#           x         y         z         u         v
# a  1.476070  0.068429 -0.567742  0.231227  0.068974
# b -0.720544  1.079304  0.317636  0.094377 -0.337972

# %% [markdown]
# ### New Column

# %%
df['New_col'] = df['x'] * df['y']

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df['New_col1'] = df['x'] * df['y'] * df['u']
df
# Out:
#           x         y         z         u         v   New_col  New_col1
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005  0.023355
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686 -0.073396
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790  1.395192
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890 -0.062997
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196 -0.676500

# %% [markdown]
# ### Delete Column

# %%
df.drop('New_col1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-cbe253958fae> in <module>
# ----> 1 df.drop('New_col1')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %% [markdown]
# * ##### Above code is not working, because it is looking for axis name New_col1. So to delete column we have to tell axis = 1

# %%
df.drop('New_col1', axis =1)
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df
# Out:
#           x         y         z         u         v   New_col  New_col1
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005  0.023355
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686 -0.073396
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790  1.395192
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890 -0.062997
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196 -0.676500

# %% [markdown]
# * ##### Again it will not be deleted permananetly. To delete it use below code.

# %%
df.drop('New_col1', axis =1 , inplace = True)

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %% [markdown]
# ### Delete Rows

# %%
df.drop('d')
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# d -1.227758  0.030047 -0.897724  1.707702 -0.330836 -0.036890
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df.drop('d', inplace = True)

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %% [markdown]
# ### Delete row from Titanic where Age is Null

# %%
np.where(titanic_train['Age'].isnull() == True)
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
ind = np.where(titanic_train['Age'].isnull() == True)

# %%
titanic_train.drop(ind[0])
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 150          151         0       2
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Accessing Data

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
# Select a and b rows
df.iloc[[0,1]]
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686

# %%
# Select a,b rows and v, New_col columns

df.iloc[[0,1], [4,5]]
# Out:
#           v   New_col
# a  0.068974  0.101005
# b -0.337972 -0.777686

# %%
df.loc[['a','b'],['v','New_col']]
# Out:
#           v   New_col
# a  0.068974  0.101005
# b -0.337972 -0.777686

# %%
df.iloc[0:2,4:]
# Out:
#           v   New_col
# a  0.068974  0.101005
# b -0.337972 -0.777686

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df>0
# Out:
#        x     y      z      u      v  New_col
# a   True  True  False   True   True     True
# b  False  True   True   True  False    False
# c   True  True  False   True   True     True
# e   True  True   True  False   True     True

# %%
df[df>0]
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429       NaN  0.231227  0.068974  0.101005
# b       NaN  1.079304  0.317636  0.094377       NaN       NaN
# c  1.201157  1.958769       NaN  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277       NaN  0.411905  0.957196

# %% [markdown]
# ### Usign Condition for Filter

# %%
df[df['x']<0]
# Out:
#           x         y         z         u         v   New_col
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686

# %%
# Record where z and v both are negative

df[(df['x']<0) & (df['v']<0) ]
# Out:
#           x         y         z         u         v   New_col
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686

# %% [markdown]
# ### Reset Index

# %%
df.reset_index()
# Out:
#   index         x         y         z         u         v   New_col
# 0     a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# 1     b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# 2     c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# 3     e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %%
df
# Out:
#           x         y         z         u         v   New_col
# a  1.476070  0.068429 -0.567742  0.231227  0.068974  0.101005
# b -0.720544  1.079304  0.317636  0.094377 -0.337972 -0.777686
# c  1.201157  1.958769 -1.099610  0.592995  0.177542  2.352790
# e  1.668007  0.573856  0.468277 -0.706752  0.411905  0.957196

# %% [markdown]
# * ##### to make changes permanent use inplace = True

# %%
df.set_index('z')
# Out:
#                   x         y         u         v   New_col
# z
# -0.567742  1.476070  0.068429  0.231227  0.068974  0.101005
#  0.317636 -0.720544  1.079304  0.094377 -0.337972 -0.777686
# -1.099610  1.201157  1.958769  0.592995  0.177542  2.352790
#  0.468277  1.668007  0.573856 -0.706752  0.411905  0.957196

# %% [markdown]
# * ##### now z column has become an index

# %% [markdown]
# ### New Data Frame for practice

# %%
df = pd.DataFrame({'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]})
df['States']="CA NV AZ".split()
df.set_index('States',inplace=True)
print(df)
# Out:
#           A    B  C
# States
# CA      1.0  5.0  1
# NV      2.0  NaN  2
# AZ      NaN  NaN  3
