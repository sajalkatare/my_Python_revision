# %%
l1 =[4,56,334,"ffd",7+5j,[4,5],(12,4,"fg","1",4.5)]

# %%
l1
# Out:
# [4, 56, 334, 'ffd', (7+5j), [4, 5], (12, 4, 'fg', '1', 4.5)]

# %%
l1[:]
# Out:
# [4, 56, 334, 'ffd', (7+5j), [4, 5], (12, 4, 'fg', '1', 4.5)]

# %%
l1[0:4]
# Out:
# [4, 56, 334, 'ffd', (7+5j), [4, 5], (12, 4, 'fg', '1', 4.5)]

# %%
l1[-4:1]
# Out:
# list

# %%
l1[3:2]
# Out:
# []

# %%
l1[-4:-1]
# Out:
# ['ffd', (7+5j), [4, 5]]

# %%
l1[-4:-10]
# Out:
# []

# %%
l1[1:-2]
# Out:
# [56, 334, 'ffd', (7+5j)]

# %%
l1[-4:-10:-1]
# Out:
# ['ffd', 334, 56, 4]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
l2 = list("str")
l2
# Out:
# ['s', 't', 'r']

# %%
l3 = [43,34,232,"dfdfdf","e3e3e"]
l3
# Out:
# [43, 34, 232, 'dfdfdf', 'e3e3e']

# %%
l3[3][-2:][::-1]
# Out:
# 'fd'

# %%
l4 = [True, False, "true",1,0,11]

# %%
l4[1]
# Out:
# False

# %%
len(l4[])
# Out:
#   File "<ipython-input-8-2731c783c1ea>", line 1
#     len(l4[])
#            ^
# SyntaxError: invalid syntax

# %%
def test(a,b):
    return a,b

# %%
test(5,6)
# Out:
# (5, 6)
