# %%
import  pandas as pd

# %%
df = pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv")

# %%
#check Data type of file

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Checking first 5 recors

df.head()
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
# 4   5                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
# 4  Provides fixed 8% short term loans to eligible...   NaN
#
# ...

# %%
# top 2 records

df.head(2)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
#
#                                        languages   latitude   longitude  \
# 0                               Spanish, Tagalog  37.477227 -122.213221
# 1  Chinese (Mandarin), Tagalog, Italian, Spanish  37.563984 -122.325799
#
#                                name  \
# 0   Fair Oaks Adult Activity Center
# 1  Second Career Employment Program
#
#                                           short_desc  \
# 0  A multipurpose senior citizens' center serving...
# ...

# %%
#Checking last rows

df.tail()
# Out:
#     id  organization_id                           accessibility admin_emails  \
# 17  18                5                cd, restroom, wheelchair          NaN
# 18  19                5              elevator, ramp, wheelchair          NaN
# 19  20                6                                     NaN          NaN
# 20  21                7                      elevator, restroom          NaN
# 21  22                8  disabled_parking, restroom, wheelchair  foo@bar.com
#
#    alternate_name                                        description  \
# 17            NaN  Provides free medical care to those in need. O...
# 18            NaN  Provides free medical and dental care to those...
# 19            NaN                                           no phone
# 20            NaN                              This is a description
# 21  The Test Spot  [NOTE THIS IS NOT A REAL ORGANIZATION--THIS IS...
#
#                email                                        languages  \
# ...

# %% [markdown]
# ##### When you dont have header in your file

# %%
pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv", header = None).head(4)
# Out:
#    0                1                                             2   \
# 0  id  organization_id                                 accessibility
# 1   1                1  disabled_parking, ramp, restroom, wheelchair
# 2   2                1                                    wheelchair
# 3   3                1                                           NaN
#
#              3               4   \
# 0  admin_emails  alternate_name
# 1           NaN             NaN
# 2           NaN             NaN
# 3           NaN             NaN
#
#                                                   5      6   \
# 0                                        description  email
# 1  A walk-in center for older adults that provide...    NaN
# 2  Provides training and job placement to eligibl...    NaN
# 3  Offers supportive counseling services to San M...    NaN
#
#                                                   7           8   \
# 0                                          languages    latitude
# ...

# %% [markdown]
# ##### Giving Custom Column names while reading file

# %%
pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv",header = None,names = ['a1','a2','b3','b2','cd','c4','a11','a21','b31','b21','cd1','c41','cd12','2'])
# Out:
#                  a1                                                 a2  \
# id  organization_id                                      accessibility
# 1                 1       disabled_parking, ramp, restroom, wheelchair
# 2                 1                                         wheelchair
# 3                 1                                                NaN
# 4                 1                                         wheelchair
# 5                 1                                         wheelchair
# 6                 2                       disabled_parking, wheelchair
# 7                 2       ramp, restroom, disabled_parking, wheelchair
# 8                 2                                                NaN
# 9                 3                         ramp, restroom, wheelchair
# 10                3  elevator, tape_braille, ramp, restroom, disabl...
# 11                3                                               ramp
# ...

# %%
#### Skiping Rows
pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv", skiprows = [1,4,6])
# Out:
#     id  organization_id                                      accessibility  \
# 0    2                1                                         wheelchair
# 1    3                1                                                NaN
# 2    5                1                                         wheelchair
# 3    7                2       ramp, restroom, disabled_parking, wheelchair
# 4    8                2                                                NaN
# 5    9                3                         ramp, restroom, wheelchair
# 6   10                3  elevator, tape_braille, ramp, restroom, disabl...
# 7   11                3                                               ramp
# 8   12                3         disabled_parking, elevator, ramp, restroom
# 9   13                3                                                NaN
# 10  14                4                                         wheelchair
# ...

# %% [markdown]
# ##### Treating any Value as Null

# %%
pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv", na_values = ["NULL"]).head(4)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                    wheelchair
# 2   3                1                                           NaN
# 3   4                1                                    wheelchair
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
#
#                                            languages   latitude   longitude  \
# 0                                   Spanish, Tagalog  37.477227 -122.213221
# ...

# %% [markdown]
# * ##### Treating "wheelchair" as Null

# %%
pd.read_csv("C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\ohana-api-master\\data\\sample-csv\\locations.csv", na_values = ["wheelchair"]).head(4)
# Out:
#    id  organization_id                                 accessibility  \
# 0   1                1  disabled_parking, ramp, restroom, wheelchair
# 1   2                1                                           NaN
# 2   3                1                                           NaN
# 3   4                1                                           NaN
#
#   admin_emails alternate_name  \
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
#
#                                          description email  \
# 0  A walk-in center for older adults that provide...   NaN
# 1  Provides training and job placement to eligibl...   NaN
# 2  Offers supportive counseling services to San M...   NaN
# 3  Provides supervised visitation services and a ...   NaN
#
#                                            languages   latitude   longitude  \
# 0                                   Spanish, Tagalog  37.477227 -122.213221
# ...

# %% [markdown]
# ### Reading Excel File

# %%
pd.read_excel('C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\poi-generated-file.xlsx').head(4)
# Out:
# C:\Users\SAJAL KATARE\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#            Name               Email           Date Of Birth   Salary
# 0  Rajeev Singh  rajeev@example.com 1992-08-21 10:07:15.979  1200000
# 1   Thomas cook  thomas@example.com 1965-11-15 10:07:15.979  1500000
# 2  Steve Maiden   steve@example.com 1987-05-18 10:07:15.979  1800000

# %% [markdown]
# ##### Reading 2nd tab of the excel sheet.

# %%
pd.read_excel('C:\\Users\\SAJAL KATARE\\Desktop\\Ineuron\\Pandas\\poi-generated-file.xlsx',sheet_name = 'salary').head(4)
# Out:
#             Date Of Birth   Salary
# 0 1992-08-21 10:07:15.979  1200000
# 1 1965-11-15 10:07:15.979  1500000
# 2 1987-05-18 10:07:15.979  1800000

# %% [markdown]
# ### Reading HTML Data

# %%
a = pd.read_html('https://www.basketball-reference.com/leaders/orb_top_10.html')

# %%
type(a)
# Out:
# list

# %% [markdown]
# * ##### HTML data will be saved as list, if miltiple tables on page then it will be element of list.
# * ##### Each Element will be a dataframe.

# %%
a[0]
# Out:
#      Season   Lg                 1st                                2nd  \
# 0   2020-21  NBA     C. Capela (297)                    E. Kanter (284)
# 1   2019-20  NBA  H. Whiteside (258)                  A. Drummond (250)
# 2   2018-19  NBA   A. Drummond (423)                     S. Adams (391)
# 3   2017-18  NBA   A. Drummond (399)                     S. Adams (384)
# 4   2016-17  NBA   A. Drummond (345)                    R. Gobert (314)
# 5   2015-16  NBA   A. Drummond (395)  R. Lopez (268), T. Thompson (268)
# 6   2014-15  NBA   A. Drummond (437)                    D. Jordan (397)
# 7   2013-14  NBA   A. Drummond (440)                    D. Jordan (331)
# 8   2012-13  NBA   Z. Randolph (310)                  T. Thompson (306)
# 9   2011-12  NBA    D. Cousins (265)                      J. Noah (242)
# 10  2010-11  NBA       K. Love (330)                  Z. Randolph (326)
# 11  2009-10  NBA   Z. Randolph (330)                    D. Howard (284)
# ...

# %% [markdown]
# ### Reading CSV from Web

# %%
#In below filew sepertor is tab

d = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv', sep = '\t')

# %%
d.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ##### Checking Datatypes of Columns in Dataframe

# %%
d.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# * ##### Object is similar to string

# %% [markdown]
# ##### Print list of columns

# %%
d.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# ##### Select only 1 column

# %%
d['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 151    1
# 152    0
# 153    0
# 154    0
# 155    0
# Name: Survived, Length: 156, dtype: int64

# %% [markdown]
# ##### Select Multiple Columns

# %%
d[['Survived', 'Pclass']]
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 151         1       1
# 152         0       3
# 153         0       3
# 154         0       3
# 155         0       1
#
# [156 rows x 2 columns]

# %% [markdown]
# ##### Difference between giving single column and giving list of columns.
# * ##### d['Survived'] will return Series.
# * ##### d[['Survived']] or d[['Survived', 'Pclass']] will return dataframe.
